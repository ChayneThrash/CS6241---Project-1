# %% [markdown]
# <a href="https://colab.research.google.com/github/ChayneThrash/CS6241---Project-1/blob/master/Parade.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp /content/drive/My\ Drive/data/robust04.tar.gz /content/robust04.tar.gz
# !cp /content/drive/My\ Drive/data/epoch=0-step=26000+90000.ckpt ./

# %%
# !tar -xvf /content/robust04.tar.gz
# Out:
# robust04/
# robust04/test.json
# robust04/training.json
# robust04/val.json

# %%
# !pip install -r /content/requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 4.7 MB 5.0 MB/s
# ...
#      |████████████████████████████████| 700 kB 73.4 MB/s
# ...
#      |████████████████████████████████| 419 kB 78.0 MB/s
# ...
#      |████████████████████████████████| 303 kB 56.0 MB/s
# ...
#      |████████████████████████████████| 8.6 MB 1.3 MB/s
# ...
#      |████████████████████████████████| 109.5 MB 43 kB/s
# ...
#      |████████████████████████████████| 596 kB 71.2 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 61.5 MB/s
# ...
#      |████████████████████████████████| 101 kB 11.2 MB/s
# ...
#      |████████████████████████████████| 5.8 MB 72.2 MB/s
# ...
#      |████████████████████████████████| 141 kB 79.1 MB/s
# ...
#      |████████████████████████████████| 72 kB 1.4 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 67.7 MB/s
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...

# %%
# !pip install cloud-tpu-client==0.10 https://storage.googleapis.com/tpu-pytorch/wheels/colab/torch_xla-1.12-cp37-cp37m-linux_x86_64.whl
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 187.4 MB 17 kB/s
# ...
#      |████████████████████████████████| 57 kB 2.9 MB/s
# ...
#   Attempting uninstall: google-api-python-client
#     Found existing installation: google-api-python-client 1.12.11
#     Uninstalling google-api-python-client-1.12.11:
#       Successfully uninstalled google-api-python-client-1.12.11
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# earthengine-api 0.1.317 requires google-api-python-client<2,>=1.12.1, but you have google-api-python-client 1.8.0 which is incompatible.
# ...

# %%
# !python run_parade_training.py ./checkpoints --data-path ./robust04 --tensorboard-logging-dir ./logs --batch-size 3 --pre-finetuning-checkpoint-path epoch=0-step=26000+90000.ckpt
# Out:
# Epoch 0:   0% 0/43750 [00:00<?, ?it/s] hi1
# hi2
# hi1
# hi2
# hi1
# hi2
# hi3
# hi4
# hi5
# hi6
# hi7
# hi8
# hi1
# hi2
# hi1
# hi2
# hi3
# hi4
# hi5
# hi1
# hi2
# Exception in device=TPU:1: torch_xla/csrc/tensor_methods.cpp:1003 : Check failed: xla::ShapeUtil::Compatible(shapes.back(), tensor_shape)
# *** Begin stack trace ***
# 	tensorflow::CurrentStackTrace()
# 	torch_xla::XLATensor::cat(absl::lts_20211102::Span<torch_xla::XLATensor const>, long)
# 	torch_xla::XLANativeFunctions::cat(c10::ArrayRef<at::Tensor>, long)
#
# 	at::_ops::cat::redispatch(c10::DispatchKeySet, c10::ArrayRef<at::Tensor>, long)
#
#
# 	at::_ops::cat::call(c10::ArrayRef<at::Tensor>, long)
#
# 	_PyMethodDef_RawFastCallKeywords
#
# 	_PyEval_EvalFrameDefault
# 	_PyFunction_FastCallDict
#
# 	PyObject_Call
# 	_PyEval_EvalFrameDefault
# 	_PyEval_EvalCodeWithName
# 	_PyFunction_FastCallDict
#
# 	_PyObject_FastCallKeywords
#
# 	_PyEval_EvalFrameDefault
# 	_PyFunction_FastCallDict
#
# 	PyObject_Call
# ...
